# %% [markdown]
# # 01 神经网络与反向传播
#
# [学习路径](../README.md) | [下一章：PyTorch](../02%20PyTorch%E4%B8%8E%E8%AE%A1%E7%AE%97%E6%9C%BA%E8%A7%86%E8%A7%89/notes.ipynb)

# %% [markdown]
# ## 原课件
#
# [打开神经网络与反向传播算法 PDF](%E7%A5%9E%E7%BB%8F%E7%BD%91%E7%BB%9C%E4%B8%8E%E5%8F%8D%E5%90%91%E4%BC%A0%E6%92%AD%E7%AE%97%E6%B3%95.pdf)
#
# 本章以原课件为学习材料。

# %% [markdown]
# ## 阅读目标与衔接
#
# 1. 理解输入、权重、偏置、激活函数与前向传播。
# 2. 区分损失函数、反向传播计算梯度与优化器更新参数。
# 3. 对照链式法则追踪梯度从输出层传回前层的过程。
#
# 完成后进入第 02 章，在 PyTorch 中对应到张量、`nn.Module`、损失函数、`backward()` 和优化器。
